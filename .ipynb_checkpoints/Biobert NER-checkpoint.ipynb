# %% [markdown]
# ### How to access to BIOBERT
# 1. https://github.com/naver/biobert-pretrained
# 2. https://github.com/dmis-lab/biobert

# %%
import requests
import pandas as pd

def query_raw(text):
    url="https://bern.korea.ac.kr/plain"
    ner=requests.post(url, data={'sample_text': text}).json()
    df=pd.json_normalize(ner)
    outdf = pd.DataFrame()
    for i in ner['denotations']:
        row = pd.json_normalize(i)
        outdf = pd.concat([outdf, row])
        outdf.reset_index(drop=True, inplace=True)

    
    return outdf

#if __name__ == '__main__':
 #   print(query_raw("YOUR TEXT HERE"))

# %%
text='SARS-CoV-2 variants are still prevalent worldwide and continue to pose a challenge to the effectiveness of current vaccines. It remains unknown whether a third dose of inactivated vaccine elicits immune potential against SARS-CoV-2 variants. Here, we showed a significant decline in plasma neutralization against SARS-CoV-2 at seven months after a second dose of the inactivated vaccine in a large-scale cohort. However, we also found that a third vaccination with an inactivated vaccine largely increased plasma neutralization against variants including Beta, Delta, and Lambda. More importantly, the high-affinity anti-RBD memory B cells were also generated by the third vaccination, suggesting a more potent and longer protection. These findings highlighted the importance and effectiveness of a third dose of inactivated vaccine in conferring higher protection against the emerging variants in populations'

# %%
ner=query_raw(text)

# %%
if len(ner) == 0:
     print( 'No BioBert entities')   
else:
    ner.reset_index(drop=True, inplace=True)
    ner['word']=0
    for i in ner.index:
        ner['word'][i]=text[ner.iloc[i]['span.begin']:ner.iloc[i]['span.end']]
    ner=ner[[ 'obj', 'word']]
# Out:
# C:\Users\FLORENCIA\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\FLORENCIA\anaconda3\lib\site-packages\pandas\core\indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
ner
# Out:
#            id      obj        word
# 0  [CUI-less]  disease  SARS-CoV-2
# 1  [CUI-less]     gene    anti-RBD

# %%
all_langs = outdf.word.unique().tolist()

# %%
all_langs
# Out:
# ['tumour',
#  'arginine',
#  'autophagy gene Atg7',
#  'mice',
#  'metabolic defect',
#  'starvation intolerance',
#  'Cancer',
#  'autophagy genes',
#  'tumours',
#  'autochthonous cancer6',
#  'Atg7',
#  'dominant-negative ATG4b',
#  'KRAS-driven cancers',
#  'KRAS',
#  'allografted tumours',
#  'argininosuccinate',
#  'argininosuccinate synthase 1',
#  'arginase I',
#  'ARG1',
#  'Atg7-deficient',
#  'ornithine',
#  'Atg5',
#  'cancer']

# %%
langs  = st.multiselect(
    "Programming languages", options=all_langs, default=all_langs, format_func=pretty
)
plot_df = ner[ner.word.isin(langs)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-146-a012e1c03f48> in <module>
# ----> 1 langs  = st.multiselect(
#       2     "Programming languages", options=all_langs, default=all_langs, format_func=pretty
#       3 )
#       4 plot_df = ner[ner.word.isin(langs)]
#
# NameError: name 'st' is not defined

# %%
plot_df = ner[ner.word.isin(all_langs)]

# %%
plot_df
# Out:
#                                                    id      obj  span.begin  \
# 0                                    [BERN:256225101]  disease          20
# 1                        [CHEBI:32696, BERN:94137403]     drug          54
# 2                                          [CUI-less]     gene         288
# 3                                    [NCBI:txid10095]  species         317
# 4         [MESH:C562803, OMIM:250620, BERN:263376801]  disease         340
# 5                      [MESH:D013217, BERN:265242001]  disease         375
# 6                      [MESH:D002277, BERN:255268301]  disease         473
# 7                                          [CUI-less]     gene         537
# 8                                    [BERN:256225101]  disease         631
# 9         [MESH:D008288, OMIM:609148, BERN:106969401]  disease         652
# 10  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene         705
# 11                                         [CUI-less]     gene         745
# 12                                   [NCBI:txid10095]  species         772
# 13                     [MESH:D010307, BERN:107530601]  disease         807
# 14  [MIM:190070, HGNC:6407, Ensembl:ENSG0000013370...     gene         807
# 15                                   [BERN:256225101]  disease         837
# 16                                   [BERN:256225101]  disease         917
# 17  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene         979
# 18                                   [BERN:257222701]  disease        1015
# 19                                   [BERN:256225101]  disease        1053
# 20                       [CHEBI:32696, BERN:94137403]     drug        1184
# 21                                   [BERN:256225101]  disease        1212
# 22                       [CHEBI:32696, BERN:94137403]     drug        1235
# 23                                     [BERN:4665803]     drug        1301
# 24  [MIM:603470, HGNC:758, Ensembl:ENSG00000130707...     gene        1301
# 25                       [CHEBI:32696, BERN:94137403]     drug        1371
# 26                                         [CUI-less]     gene        1397
# 27  [MIM:608313, HGNC:663, Ensembl:ENSG00000118520...     gene        1409
# 28                                         [CUI-less]  disease        1437
# 29  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene        1437
# 30                       [CHEBI:32696, BERN:94137403]     drug        1471
# 31                       [CHEBI:32696, BERN:94137403]     drug        1522
# 32                      [CHEBI:44667, BERN:270478003]     drug        1547
# 33  [MIM:608313, HGNC:663, Ensembl:ENSG00000118520...     gene        1558
# 34  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene        1689
# 35  [MIM:608313, HGNC:663, Ensembl:ENSG00000118520...     gene        1715
# 36                       [CHEBI:32696, BERN:94137403]     drug        1744
# 37                                   [BERN:256225101]  disease        1757
# 38  [MIM:604261, HGNC:589, Ensembl:ENSG00000057663...     gene        1784
# 39                       [CHEBI:32696, BERN:94137403]     drug        1845
# 40  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene        1984
# 41  [MIM:608760, HGNC:16935, Ensembl:ENSG000001975...     gene        2017
# 42                       [CHEBI:32696, BERN:94137403]     drug        2043
# 43                       [CHEBI:32696, BERN:94137403]     drug        2093
# 44                                   [BERN:256225101]  disease        2106
# 45  [MIM:608313, HGNC:663, Ensembl:ENSG00000118520...     gene        2183
# 46                       [CHEBI:32696, BERN:94137403]     drug        2238
# 47                                   [BERN:256225101]  disease        2271
# 48                     [MESH:D002277, BERN:255268301]  disease        2331
#
#     span.end                          word
# 0         26                        tumour
# 1         62                      arginine
# 2        307           autophagy gene Atg7
# 3        321                          mice
# 4        356              metabolic defect
# 5        397        starvation intolerance
# 6        479                        Cancer
# 7        552               autophagy genes
# 8        638                       tumours
# 9        673         autochthonous cancer6
# 10       709                          Atg7
# 11       768       dominant-negative ATG4b
# 12       776                          mice
# 13       826           KRAS-driven cancers
# 14       811                          KRAS
# 15       843                        tumour
# 16       923                        tumour
# 17       983                          Atg7
# 18      1034           allografted tumours
# 19      1059                        tumour
# 20      1192                      arginine
# 21      1218                        tumour
# 22      1243                      arginine
# 23      1318             argininosuccinate
# 24      1329  argininosuccinate synthase 1
# 25      1379                      arginine
# 26      1407                    arginase I
# 27      1413                          ARG1
# 28      1451                Atg7-deficient
# 29      1441                          Atg7
# 30      1479                      arginine
# 31      1530                      arginine
# 32      1556                     ornithine
# 33      1562                          ARG1
# 34      1693                          Atg7
# 35      1719                          ARG1
# 36      1752                      arginine
# 37      1763                        tumour
# 38      1788                          Atg5
# 39      1853                      arginine
# 40      1988                          Atg7
# 41      2021                          Atg7
# 42      2051                      arginine
# 43      2101                      arginine
# 44      2112                        tumour
# 45      2187                          ARG1
# 46      2246                      arginine
# 47      2277                        tumour
# 48      2337                        cancer
